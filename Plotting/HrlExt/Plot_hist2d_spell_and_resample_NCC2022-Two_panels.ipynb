# %%
import xarray as xr
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import NullFormatter

import epicc_config as cfg

# %%
#GEO INFO
geo_file = xr.open_dataset(cfg.geofile_ref)
lm_is=geo_file.LANDMASK.squeeze()
lm_is=lm_is.rename({'west_east':'x','south_north':'y'})

# %%
#LOADING DATA
#####################################################################
#####################################################################
wet_th = '_0.1mm'

wrun_pre = cfg.wrf_runs[0]
wrun_fut = wrun_pre.replace("ERA5","ERA5_CMIP6anom")

fin_pre_land = xr.open_dataset(f'{cfg.path_in}/{wrun_pre}/hist2d_spell_IFD_2013-2020_land_sum_WME{wet_th}.nc')
fin_fut_land = xr.open_dataset(f'{cfg.path_in}/{wrun_fut}/hist2d_spell_IFD_2013-2020_land_sum_WME{wet_th}.nc')

I_bins_spell = np.asarray(list(range(1,6,1)) + list(range(6,582,6)))
I_bins_intensity = np.asarray([1,5] + list(range(10,505,5)))
X,Y=np.meshgrid(I_bins_spell,I_bins_intensity)

# %%
fin_pre_land.histogram_spell_intensity.values.T[:,0]
# Out:
# array([1.428807e+06, 3.788000e+03, 4.400000e+01, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00])

# %%
ylim = 500

fig = plt.figure(figsize=(15,7.5),constrained_layout=False)
widths = [1,4,1,4,1]
heights = [0.45,0.45]
spec = fig.add_gridspec(ncols=5, nrows=2, width_ratios=widths,
                      height_ratios=heights)

ax1 = fig.add_subplot(spec[0, 0])
imp1=ax1.pcolormesh(X[:,:6],Y[:,:6],fin_pre_land.histogram_spell_intensity.values.T[:,:6],cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=1,vmax=100000))
ax1.set_ylabel('mm')
ax1.set_xticks([0.5,1.5,2.5,3.5,4.5,5.5])
ax1.set_xticklabels([10,20,30,40,50,60])
# Out:
# /tmp/ipykernel_20763/1110064265.py:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   imp1=ax1.pcolormesh(X[:,:6],Y[:,:6],fin_pre_land.histogram_spell_intensity.values.T[:,:6],cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=1,vmax=100000))
# [Text(0.5, 0, '10'),
#  Text(1.5, 0, '20'),
#  Text(2.5, 0, '30'),
#  Text(3.5, 0, '40'),
#  Text(4.5, 0, '50'),
#  Text(5.5, 0, '60')]

# %%
xticks = [0]+list(np.arange(6,582,36))
xtickslabels = list(range(0,102,6))


set_lim = False
xlim = 101
ylim = 500

fig = plt.figure(figsize=(20, 10))
ax1=fig.add_subplot(2,2,1)
ax1.set_title("a present",loc='left',fontsize='xx-large',fontweight='bold')
ax1.set_ylim(5,ylim)
if set_lim is True:
    ax1.set_xlim(0,xlim)
imp1=ax1.pcolormesh(X,Y,fin_pre_land.histogram_spell_intensity.values.T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=1,vmax=100000))
#ax1.set_xlabel('minutes')
ax1.set_ylabel('mm')
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtickslabels)
cb1=plt.colorbar(imp1,ax=ax1)
cb1.set_label('# of events')

ax2=fig.add_subplot(2,2,2)
ax2.set_title("b future",loc='left',fontsize='xx-large',fontweight='bold')
ax2.set_ylim(5,ylim)
if set_lim is True:
    ax2.set_xlim(0,xlim)
imf1=ax2.pcolormesh(X,Y,fin_fut_land.histogram_spell_intensity.values.T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=1,vmax=100000))

#ax2.set_xlabel('hours')
ax2.set_ylabel('mm')
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtickslabels)
cb2=plt.colorbar(imf1,ax=ax2)
cb2.set_label('# of events')

ax3= fig.add_subplot(2,2,3)
cmap = plt.get_cmap('RdBu')
ax3.set_ylim(5,ylim)
if set_lim is True:
    ax3.set_xlim(0,xlim)
#cmap = utils.rgb2cmap("/home/dargueso/share/colormaps/my_BlueWhiteOrangeRed_HESSD_reversed.rgb")
levels=np.arange(-150,160,10)
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
# norm = mcolors.SymLogNorm(linthresh=10, linscale=0.5,
#                                               vmin=-200, vmax=200)
ax3.set_title("c rel. change",loc='left',fontsize='xx-large',fontweight='bold')
ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.histogram_spell_intensity.values)-np.nan_to_num(fin_pre_land.histogram_spell_intensity.values))*100./np.nan_to_num(fin_pre_land.histogram_spell_intensity.values)).T,cmap=cmap, norm=norm)

ax3.set_xlabel('hours')
ax3.set_ylabel('mm')
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtickslabels)
cb3=plt.colorbar(ctch,ax=ax3)
cb3.set_label('Change(%)')

ax4= fig.add_subplot(2,2,4)
cmap = plt.get_cmap('RdBu')
ax4.set_ylim(5,ylim)
if set_lim is True:
    ax4.set_xlim(0,xlim)
#cmap = utils.rgb2cmap("/home/dargueso/share/colormaps/my_BlueWhiteOrangeRed_HESSD_reversed.rgb")
#levels=np.arange(-2000,2100,100)
#norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
norm = mcolors.SymLogNorm(linthresh=100, linscale=1,
                                              vmin=-200000, vmax=200000)
ax4.set_title("d abs. change",loc='left',fontsize='xx-large',fontweight='bold')
ctch=ax4.pcolormesh(X,Y,(np.nan_to_num(fin_fut_land.histogram_spell_intensity.values)-np.nan_to_num(fin_pre_land.histogram_spell_intensity.values)).T,cmap=cmap, norm=norm)


ax4.set_xlabel('hours')
ax4.set_ylabel('mm')
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtickslabels)
cb4=plt.colorbar(ctch,ax=ax4)
cb4.set_label('Abs. change')
plt.savefig(f'Changes_IFD_accum_EPICC{wet_th}.png',dpi=150)
# Out:
# /tmp/ipykernel_15583/2023352563.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.histogram_spell_intensity.values)-np.nan_to_num(fin_pre_land.histogram_spell_intensity.values))*100./np.nan_to_num(fin_pre_land.histogram_spell_intensity.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/2023352563.py:48: RuntimeWarning: invalid value encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.histogram_spell_intensity.values)-np.nan_to_num(fin_pre_land.histogram_spell_intensity.values))*100./np.nan_to_num(fin_pre_land.histogram_spell_intensity.values)).T,cmap=cmap, norm=norm)

# %%
#LOADING DATA
#####################################################################
#####################################################################

wrun_pre = cfg.wrf_runs[0]
wrun_fut = wrun_pre.replace("ERA5","ERA5_CMIP6anom")

fin_pre_land = xr.open_dataset(f'{cfg.path_in}/{wrun_pre}/hist2d_resample_time_IFD_2013-2020_land_sum_WME{wet_th}.nc')#.isel(Ibins=slice(2,None))
fin_fut_land = xr.open_dataset(f'{cfg.path_in}/{wrun_fut}/hist2d_resample_time_IFD_2013-2020_land_sum_WME{wet_th}.nc')#.isel(Ibins=slice(2,None))

RSmins = np.asarray([0,10,20,30,60,120,180,360,480,720,1440])
I_bins_edges= np.arange(0,505,5)

X,Y=np.meshgrid(range(len(RSmins)),I_bins_edges)

# %%
fin_fut_land.Ibins
ax1.set_xticks([0]+list(np.arange(4,10.5)))
ax1.set_xticklabels([0,1,2,3,6,8,12,24])
# Out:
# [Text(0.0, 0, '0'),
#  Text(4.0, 0, '1'),
#  Text(5.0, 0, '2'),
#  Text(6.0, 0, '3'),
#  Text(7.0, 0, '6'),
#  Text(8.0, 0, '8'),
#  Text(9.0, 0, '12'),
#  Text(10.0, 0, '24')]

# %%
[0]+list(np.arange(3,10.5))
# Out:
# [0, 3.0, 4.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0]

# %%
fin_fut_land.Ibins.shape
# Out:
# (100,)

# %%
fig = plt.figure(figsize=(20, 10))
ax1=fig.add_subplot(2,2,1)
ax1.set_title("a present",loc='left',fontsize='xx-large',fontweight='bold')
ax1.set_ylim(0,250)
imp1=ax1.pcolormesh(X,Y,np.nan_to_num(fin_pre_land.FRQ.values).T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=0.1,vmax=100000))

ax1.set_xticks(list(np.arange(3.5,10)))
ax1.set_xticklabels([1,2,3,6,8,12,24])

ax1.set_xlabel('hours')
ax1.set_ylabel('mm')
cb1=plt.colorbar(imp1,ax=ax1)
cb1.set_label('# of events')

ax2=fig.add_subplot(2,2,2)
ax2.set_title("b future",loc='left',fontsize='xx-large',fontweight='bold')
ax2.set_ylim(0,250)

imf1=ax2.pcolormesh(X,Y,np.nan_to_num(fin_fut_land.FRQ.values).T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=0.1,vmax=100000))
ax2.set_xlabel('hours')
ax2.set_ylabel('mm')
cb2=plt.colorbar(imf1,ax=ax2)
cb2.set_label('# of events')

ax3= fig.add_subplot(2,2,3)
cmap = plt.get_cmap('RdBu')
ax3.set_ylim(0,250)

#cmap = utils.rgb2cmap("/home/dargueso/share/colormaps/my_BlueWhiteOrangeRed_HESSD_reversed.rgb")
levels=np.arange(-150,160,10)
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
# norm = mcolors.SymLogNorm(linthresh=10, linscale=0.5,
#                                               vmin=-200, vmax=200)
ax3.set_title("c rel. change",loc='left',fontsize='xx-large',fontweight='bold')
ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
ax3.set_xlabel('hours')
ax3.set_ylabel('mm')
cb3=plt.colorbar(ctch,ax=ax3)
cb3.set_label('Change(%)')

ax4= fig.add_subplot(2,2,4)
cmap = plt.get_cmap('RdBu')
ax4.set_ylim(0,250)

#cmap = utils.rgb2cmap("/home/dargueso/share/colormaps/my_BlueWhiteOrangeRed_HESSD_reversed.rgb")
#levels=np.arange(-2000,2100,100)
#norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
norm = mcolors.SymLogNorm(linthresh=10, linscale=1,
                                              vmin=-100000, vmax=100000)
ax4.set_title("d abs. change",loc='left',fontsize='xx-large',fontweight='bold')
ctch=ax4.pcolormesh(X,Y,(np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
ax4.set_xlabel('hours')
ax4.set_ylabel('mm')
cb4=plt.colorbar(ctch,ax=ax4)
cb4.set_label('Abs. change')
#plt.savefig(f'Changes_IFD_accum_{island}.png')
# Out:
# /tmp/ipykernel_15583/2509185109.py:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   imp1=ax1.pcolormesh(X,Y,np.nan_to_num(fin_pre_land.FRQ.values).T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=0.1,vmax=100000))
# /tmp/ipykernel_15583/2509185109.py:19: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   imf1=ax2.pcolormesh(X,Y,np.nan_to_num(fin_fut_land.FRQ.values).T,cmap=plt.cm.viridis,norm=mcolors.LogNorm(vmin=0.1,vmax=100000))
# /tmp/ipykernel_15583/2509185109.py:35: RuntimeWarning: divide by zero encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/2509185109.py:35: RuntimeWarning: invalid value encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/2509185109.py:35: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/2509185109.py:51: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ctch=ax4.pcolormesh(X,Y,(np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)

# %%
fig = plt.figure(figsize=(20, 10))
ax3= fig.add_subplot(1,1,1)
cmap = plt.get_cmap('RdBu')
ax3.set_ylim(0,250)
ax3.set_xticks(list(np.arange(3.5,10)))
ax3.set_xticklabels([1,2,3,6,8,12,24])
#cmap = utils.rgb2cmap("/home/dargueso/share/colormaps/my_BlueWhiteOrangeRed_HESSD_reversed.rgb")
levels=np.arange(-200,210,10)
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
# norm = mcolors.SymLogNorm(linthresh=10, linscale=0.5,
#                                               vmin=-200, vmax=200)
ax3.set_title("Resampled rel. change",loc='left',fontsize='xx-large',fontweight='bold')
ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
ax3.set_xlabel('hours')
ax3.set_ylabel('mm')
cb3=plt.colorbar(ctch,ax=ax3)
cb3.set_label('Change(%)')

plt.savefig(f'Changes_IFD_resampled.png',dpi=150)
# Out:
# /tmp/ipykernel_15583/158054955.py:13: RuntimeWarning: divide by zero encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/158054955.py:13: RuntimeWarning: invalid value encountered in true_divide
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
# /tmp/ipykernel_15583/158054955.py:13: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ctch=ax3.pcolormesh(X,Y,((np.nan_to_num(fin_fut_land.FRQ.values)-np.nan_to_num(fin_pre_land.FRQ.values))*100./np.nan_to_num(fin_pre_land.FRQ.values)).T,cmap=cmap, norm=norm)
